# %% [markdown]
# <hr>

# %% [markdown]
# # Data Acquisition

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2>Read Data</h2>

# %%
file_name = "PersianBooks_Dataset.csv"
df = pd.read_csv(file_name)

# %%
# show the first 10 rows of dataset
print("The first 10 rows of the dataframe: ")
df.head(10)
# Out:
# The first 10 rows of the dataframe:
#    book_id                                title  \
# 0      100  هفت گام برای شروع موفق یک کسب و کار
# 1      104                           صدف نبوت 4
# 2      107                         مرآت ولایت ۲
# 3      108                         مرآت ولایت ۳
# 4      109                         مرآت ولایت ۴
# 5      110                         مرآت ولایت ۵
# 6      112                   یک ماه خون گرفته ۵
# 7      113                   یک ماه خون گرفته ۴
# 8      114                         بهار امامت ۴
# 9      115                         بهار امامت ۳
#
#                                          description  price  number_of_page  \
# 0  داشتن کسب‌وکاری مستقل، برای بسیاری به‌ویژه جوا...   2000              76
# 1  مجموعه اشعار مناسبت های ایام فاطمیه ،ماه های ج...   5000             128
# 2  مجموعه شعر آیینی- شیعی مرآت ولایت نوشته غلامرض...   5000             193
# 3  مجموعه شعر آیینی- شیعی مرآت ولایت نوشته غلامرض...   5000             203
# ...

# %%
# Print the last 10 rows 
print("The last 10 rows of the dataframe\n")
df.tail(10)
# Out:
# The last 10 rows of the dataframe
#        book_id                                              title  \
# 15698    45448                                      بابا لنگ‌دراز
# 15699    45449                                 روش برداشت از قرآن
# 15700    45451  مجموعه مقالات پنجمین همایش ملی تحلیل گفتمان و ...
# 15701    45452                                       اصلی و کَرَم
# 15702    45455  قیرمیزی بالیق؛ به انضمام متن اصلی ماهی سیاه کو...
# 15703    45457                                غزلیات علی آغا واحد
# 15704    45459  روانشناسی جنسی؛ رویکردی تکاملی به جذابیت تنوع‌...
# 15705    45460                        English grammar in practice
# 15706    45475                          روش برداشت از نهج‌البلاغه
# 15707    45480  فرمول برنامه‌ریزی؛ راهنمایی برای ایجاد فهرست‌ه...
#
#                                              description  price  \
# 15698  کتاب گویای «بابا لنگ‌دراز» مشهورترین اثر جین و...  12000
# 15699  هر کسی برای استفاده از قرآن راهی در پیش گرفته ...   3500
# ...

# %%
print(df.dtypes)
# Out:
# book_id              int64
# title               object
# description         object
# price                int64
# number_of_page       int64
# PhysicalPrice        int64
# publishDate         object
# rating             float64
# publisher           object
# coveruri            object
# number_of_q          int64
# categories          object
# number_of_cm         int64
# author_name         object
# translator_name     object
# lang                object
# dtype: object

# %%
df.describe()
# Out:
#             book_id         price  number_of_page  PhysicalPrice  \
# count  15708.000000  15708.000000    15708.000000   15708.000000
# mean   24609.641075   6887.797746      183.540807    9831.277438
# std    12312.011287   5916.053279      205.438371   16027.298323
# min      100.000000      0.000000        0.000000       0.000000
# 25%    14733.500000   3000.000000       64.000000       0.000000
# 50%    25057.500000   5000.000000      141.000000    4000.000000
# 75%    35019.500000   9500.000000      250.250000   15000.000000
# max    45480.000000  97500.000000     5721.000000  480000.000000
#
#              rating   number_of_q  number_of_cm
# count  10951.000000  15708.000000  15708.000000
# mean       3.992425      1.719379      1.557296
# std        1.059488      3.415321      1.885185
# min        0.500000      0.000000      0.000000
# 25%        3.500000      0.000000      0.000000
# 50%        4.230769      0.000000      1.000000
# ...

# %%
# describe all the columns in "df"
df.describe(include = 'all')
# Out:
#              book_id         title  \
# count   15708.000000         15708
# unique           NaN         15166
# top              NaN  شازده کوچولو
# freq             NaN             6
# mean    24609.641075           NaN
# std     12312.011287           NaN
# min       100.000000           NaN
# 25%     14733.500000           NaN
# 50%     25057.500000           NaN
# 75%     35019.500000           NaN
# max     45480.000000           NaN
#
#                                               description         price  \
# count                                               15707  15708.000000
# unique                                              15392           NaN
# top     مجموعه‌ی سی جلدی «نمایشنامه‌های آسان» متناسب ب...           NaN
# freq                                                   29           NaN
# mean                                                  NaN   6887.797746
# std                                                   NaN   5916.053279
# ...

# %%
df[['number_of_page', 'price']].describe()
# Out:
#        number_of_page         price
# count    15708.000000  15708.000000
# mean       183.540807   6887.797746
# std        205.438371   5916.053279
# min          0.000000      0.000000
# 25%         64.000000   3000.000000
# 50%        141.000000   5000.000000
# 75%        250.250000   9500.000000
# max       5721.000000  97500.000000

# %% [markdown]
# <h2>Info</h2>

# %%
# Look at info of "df"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   book_id          15708 non-null  int64
#  1   title            15708 non-null  object
#  2   description      15707 non-null  object
#  3   price            15708 non-null  int64
#  4   number_of_page   15708 non-null  int64
#  5   PhysicalPrice    15708 non-null  int64
#  6   publishDate      13285 non-null  object
#  7   rating           10951 non-null  float64
#  8   publisher        15708 non-null  object
#  9   coveruri         15708 non-null  object
#  10  number_of_q      15708 non-null  int64
#  11  categories       15708 non-null  object
#  12  number_of_cm     15708 non-null  int64
#  13  author_name      15708 non-null  object
#  14  translator_name  7766 non-null   object
#  15  lang             15708 non-null  object
# dtypes: float64(1), int64(6), object(9)
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# <h2>Identify missing values</h2>

# %%
missing_data = df.isnull()
missing_data.head(20)
# Out:
#     book_id  title  description  price  number_of_page  PhysicalPrice  \
# 0     False  False        False  False           False          False
# 1     False  False        False  False           False          False
# 2     False  False        False  False           False          False
# 3     False  False        False  False           False          False
# 4     False  False        False  False           False          False
# 5     False  False        False  False           False          False
# 6     False  False        False  False           False          False
# 7     False  False        False  False           False          False
# 8     False  False        False  False           False          False
# 9     False  False        False  False           False          False
# 10    False  False        False  False           False          False
# 11    False  False        False  False           False          False
# ...

# %% [markdown]
# In this Dataset we don't have missing data but if we have we could use numpy library to replce it.

# %%
# replace "?" to NaN
# df.replace("?", np.nan, inplace = True)
# df.head(5)

# %% [markdown]
# <h2> Count missing Values in each column </h2>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# book_id
# book_id
# False    15708
# Name: count, dtype: int64
#
# title
# title
# False    15708
# Name: count, dtype: int64
#
# description
# description
# False    15707
# True         1
# Name: count, dtype: int64
#
# price
# price
# False    15708
# Name: count, dtype: int64
#
# number_of_page
# number_of_page
# False    15708
# Name: count, dtype: int64
#
# PhysicalPrice
# PhysicalPrice
# False    15708
# Name: count, dtype: int64
#
# publishDate
# publishDate
# False    13285
# True      2423
# Name: count, dtype: int64
#
# rating
# rating
# False    10951
# True      4757
# Name: count, dtype: int64
#
# publisher
# publisher
# False    15708
# Name: count, dtype: int64
#
# coveruri
# coveruri
# False    15708
# Name: count, dtype: int64
#
# number_of_q
# number_of_q
# False    15708
# Name: count, dtype: int64
#
# categories
# categories
# False    15708
# Name: count, dtype: int64
#
# number_of_cm
# number_of_cm
# False    15708
# Name: count, dtype: int64
#
# author_name
# ...

# %% [markdown]
# <h2>Deal with missing data</h2>

# %% [markdown]
# If we had missing data, we had two options the first one was to Drop data and the second one was to Replace data. Let's see how it works:

# %%
# Calculate the mean and replace the nan values with the average
# avg_loss = df['price'].astype("float").mean(axis = 0)
# df["price"].replace(np.nan, avg_loss, inplace = True)

# %%
df['price'].value_counts()
# Out:
# price
# 5000     1156
# 3000      944
# 10000     830
# 4000      813
# 6000      756
#          ...
# 17250       1
# 28750       1
# 8880        1
# 16850       1
# 4550        1
# Name: count, Length: 453, dtype: int64

# %% [markdown]
# <h2>Correct  data format</h2>

# %%
df.dtypes
# Out:
# book_id              int64
# title               object
# description         object
# price                int64
# number_of_page       int64
# PhysicalPrice        int64
# publishDate         object
# rating             float64
# publisher           object
# coveruri            object
# number_of_q          int64
# categories          object
# number_of_cm         int64
# author_name         object
# translator_name     object
# lang                object
# dtype: object

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %% [markdown]
# In our dataset, all datatypes are correct unless the price column.

# %%
df[['price']] = df[['price']].astype('float')

# %% [markdown]
# <h2>Data Standardization </h2>
